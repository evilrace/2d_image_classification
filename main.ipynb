# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from PIL import Image
import numpy as np 

data_path = r'D:\dataset\kagglecatsanddogs_5340\PetImages'
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
## load dataset 
image_size = (180, 180)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    validation_split = 0.2,
    subset = 'training',
    image_size = image_size,
    batch_size = batch_size,
    seed = 1337,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    validation_split = 0.2,
    subset = 'validation',
    image_size = image_size,
    batch_size = batch_size,
    seed = 1337,
)
# Out:
# Num GPUs Available:  1
# Found 23422 files belonging to 2 classes.
# Using 18738 files for training.
# Found 23422 files belonging to 2 classes.
# Using 4684 files for validation.

# %%
# ## delete unsupported image files.

# import os

# num_skipped = 0

# for folder_name in ('Cat', 'Dog'):
#     folder_path = os.path.join(data_path, folder_name)
#     for fname in os.listdir(folder_path):
#         fpath = os.path.join(folder_path, fname)
#         try:
#             fobj = open(fpath, 'rb')
#             is_jfif = tf.compat.as_bytes('JFIF') in fobj.peek(10)
#         finally:
#             fobj.close()

#         if not is_jfif:
#             num_skipped += 1
#             # delete corrupted images
#             os.remove(fpath)

# %%
## visualize data samples
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3,3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(int(labels[i]))
        plt.axis('off')
    plt.show()

# %%
# data augmentation
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip('horizontal'),
        layers.RandomRotation(0.1)
    ]
)

# %%
# visualize data augmentation
plt.figure(figsize=(10,10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype('uint8'))
        plt.axis('off')

# %%
# prefetch data for performance

train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %%
# build a model

def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)

    x = layers.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides = 2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(64, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    previous_block_activation = x
    
    for size in [128, 256, 512, 728]:
        x = layers.Activation('relu')(x)
        x = layers.SeparableConv2D(size, 3, padding='same')(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation('relu')(x)
        x = layers.SeparableConv2D(size, 3, padding='same')(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding='same')(x)

        residual = layers.Conv2D(size, 1, strides = 2, padding='same')(
            previous_block_activation
        )

        # add back residual
        x = layers.add([x, residual])
        previous_block_activation = x


    x = layers.SeparableConv2D(size, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.GlobalAveragePooling2D()(x)

    if num_classes == 2:
        activation = 'sigmoid'
        units = 1
    else:
        activation = 'softmax'
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

# %%
# compile a model

model = make_model(input_shape=image_size + (3,), num_classes=2)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
# train the model

epochs = 50

callbacks = [
    keras.callbacks.ModelCheckpoint('save_at_{epoch}.h5'),
]

model.compile(
    optimizer = keras.optimizers.Adam(1e-3),
    loss = keras.losses.BinaryCrossentropy(),
    metrics = [keras.metrics.BinaryAccuracy()],
)
model.summary()

model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds
    )
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  sequential_1 (Sequential)      (None, 180, 180, 3)  0           ['input_5[0][0]']
#
#  rescaling_4 (Rescaling)        (None, 180, 180, 3)  0           ['sequential_1[2][0]']
#
#  conv2d_12 (Conv2D)             (None, 90, 90, 32)   896         ['rescaling_4[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 90, 90, 32)  128         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 90, 90, 32)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 90, 90, 64)   18496       ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 90, 90, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 90, 90, 64)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 90, 90, 64)   0           ['activation_17[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 90, 90, 128)  8896       ['activation_18[0][0]']
#  onv2D)
#
#  batch_normalization_18 (BatchN  (None, 90, 90, 128)  512        ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 90, 90, 128)  0           ['batch_normalization_18[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 90, 90, 128)  17664      ['activation_19[0][0]']
#  onv2D)
#
#  batch_normalization_19 (BatchN  (None, 90, 90, 128)  512        ['separable_conv2d_9[0][0]']
#  ormalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 45, 45, 128)  0          ['batch_normalization_19[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 45, 45, 128)  8320        ['activation_17[0][0]']
#
#  add_4 (Add)                    (None, 45, 45, 128)  0           ['max_pooling2d_4[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  activation_20 (Activation)     (None, 45, 45, 128)  0           ['add_4[0][0]']
#
#  separable_conv2d_10 (Separable  (None, 45, 45, 256)  34176      ['activation_20[0][0]']
#  Conv2D)
#
#  batch_normalization_20 (BatchN  (None, 45, 45, 256)  1024       ['separable_conv2d_10[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 45, 45, 256)  0           ['batch_normalization_20[0][0]']
#
#  separable_conv2d_11 (Separable  (None, 45, 45, 256)  68096      ['activation_21[0][0]']
#  Conv2D)
#
#  batch_normalization_21 (BatchN  (None, 45, 45, 256)  1024       ['separable_conv2d_11[0][0]']
#  ormalization)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 23, 23, 256)  0          ['batch_normalization_21[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 23, 23, 256)  33024       ['add_4[0][0]']
#
#  add_5 (Add)                    (None, 23, 23, 256)  0           ['max_pooling2d_5[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  activation_22 (Activation)     (None, 23, 23, 256)  0           ['add_5[0][0]']
#
#  separable_conv2d_12 (Separable  (None, 23, 23, 512)  133888     ['activation_22[0][0]']
#  Conv2D)
#
#  batch_normalization_22 (BatchN  (None, 23, 23, 512)  2048       ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 23, 23, 512)  0           ['batch_normalization_22[0][0]']
#
#  separable_conv2d_13 (Separable  (None, 23, 23, 512)  267264     ['activation_23[0][0]']
#  Conv2D)
#
#  batch_normalization_23 (BatchN  (None, 23, 23, 512)  2048       ['separable_conv2d_13[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 512)  0          ['batch_normalization_23[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 12, 12, 512)  131584      ['add_5[0][0]']
#
#  add_6 (Add)                    (None, 12, 12, 512)  0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  activation_24 (Activation)     (None, 12, 12, 512)  0           ['add_6[0][0]']
#
#  separable_conv2d_14 (Separable  (None, 12, 12, 728)  378072     ['activation_24[0][0]']
#  Conv2D)
#
#  batch_normalization_24 (BatchN  (None, 12, 12, 728)  2912       ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 12, 12, 728)  0           ['batch_normalization_24[0][0]']
#
#  separable_conv2d_15 (Separable  (None, 12, 12, 728)  537264     ['activation_25[0][0]']
#  Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 12, 12, 728)  2912       ['separable_conv2d_15[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 6, 6, 728)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 6, 6, 728)    373464      ['add_6[0][0]']
#
#  add_7 (Add)                    (None, 6, 6, 728)    0           ['max_pooling2d_7[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  separable_conv2d_16 (Separable  (None, 6, 6, 728)   537264      ['add_7[0][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 6, 6, 728)   2912        ['separable_conv2d_16[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 6, 6, 728)    0           ['batch_normalization_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 728)         0           ['activation_26[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 728)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1)            729         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2,565,385
# Trainable params: 2,557,241
# Non-trainable params: 8,144
# __________________________________________________________________________________________________
# Epoch 1/50
# 586/586 [==============================] - 213s 352ms/step - loss: 0.6375 - binary_accuracy: 0.6454 - val_loss: 0.5974 - val_binary_accuracy: 0.6778
# Epoch 2/50
#  15/586 [..............................] - ETA: 3:21 - loss: 0.5218 - binary_accuracy: 0.7583

# %%
# run inference on new data

image = keras.preprocessing.image.load_img(
    f"{data_path}/Cat/6779.jpg", target_size = image_size
)

img_array = keras.preprocessing.image.img_to_array(image)
img_array = tf.expand_dims(img_array, 0) # create batch axis

predictions = model.predict(img_array)
score = predictions[0]
print(
    'This image is %.2f percent cat and %.2f percent dog.' 
    % (100 * (1 - score), 100 * score)
)
