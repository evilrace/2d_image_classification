# %%
# import modules
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
num_classes = 10
input_shape = (28, 28, 1)

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# scale image to the [0, 1] range
x_train = x_train.astype('float32') / 255
x_test  = x_test.astype('float32') / 255

# convert image shape from (28, 28) to (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# check image shape
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(y_train.shape[0], 'test samples')

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 60000 test samples

# %%
# convert to tf dataset from numpy dataset
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
train_ds = train_ds.batch(128).prefetch(128)
test_ds = test_ds.batch(128).prefetch(128)

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_32 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 11, 11, 64)        18496
#
#  max_pooling2d_33 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_16 (Flatten)        (None, 1600)              0
#
#  dropout_16 (Dropout)        (None, 1600)              0
#
#  dense_16 (Dense)            (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 32
epochs = 15

optimizer = keras.optimizers.Adam(1e-3)
loss = keras.losses.CategoricalCrossentropy()
metrics = [keras.metrics.CategoricalAccuracy()]


model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

model.fit(x_train, y_train, epochs=epochs)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0210 - categorical_accuracy: 0.9934
# Epoch 2/15
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0172 - categorical_accuracy: 0.9943
# Epoch 3/15
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0192 - categorical_accuracy: 0.9936
# Epoch 4/15
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0188 - categorical_accuracy: 0.9936
# Epoch 5/15
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0181 - categorical_accuracy: 0.9934
# Epoch 6/15
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0176 - categorical_accuracy: 0.9940
# Epoch 7/15
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0163 - categorical_accuracy: 0.9943
# Epoch 8/15
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0176 - categorical_accuracy: 0.9942
# Epoch 9/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0180 - categorical_accuracy: 0.9940
# Epoch 10/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0157 - categorical_accuracy: 0.9946
# Epoch 11/15
# 1184/1875 [=================>............] - ETA: 4s - loss: 0.0158 - categorical_accuracy: 0.9945

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.02662009932100773
# Test accuracy: 0.9932000041007996
